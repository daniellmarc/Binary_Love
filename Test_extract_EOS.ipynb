# %%
# !pip install lalsimulation >= 5.0.0.1

# %%
import lalsimulation as lalsim
import lal 
import sys
sys.path.insert(0,'/home/marc.penuliar/bilby') 
import bilby
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

# %%
results = bilby.result.read_in_result(filename='binary_love_Symm/outdir/bns_example_result.json') #Binary_love_Symm

# %%
# eos5 = lalsim.SimNeutronStarEOSByName("LS220") # Wrong name

# %%
eos0 = lalsim.SimNeutronStarEOSByName("SLY")
eos1 = lalsim.SimNeutronStarEOSByName("ALF2")
eos2 = lalsim.SimNeutronStarEOSByName("H4")
eos3 = lalsim.SimNeutronStarEOSByName("MPA1")
eos4 = lalsim.SimNeutronStarEOSByName("ENG")
# eos5 = lalsim.SimNeutronStarEOSByName("LS220")
# eos6 = lalsim.SimNeutronStarEOSByName("2B")
# eos7 = lalsim.SimNeutronStarEOSByName("G2K123")
# eos8 = lalsim.SimNeutronStarEOSByName("DD2")
# eos9 = lalsim.SimNeutronStarEOSByName("G2")
# eos10 = lalsim.SimNeutronStarEOSByName("SFHO")
# eos11 = lalsim.SimNeutronStarEOSByName("2H")
# eos12 = lalsim.SimNeutronStarEOSByName("BHBLP")
eos13 = lalsim.SimNeutronStarEOSByName("HQC18")
eos14 = lalsim.SimNeutronStarEOSByName("SKOP")
eos15 = lalsim.SimNeutronStarEOSByName("BHF_BBB2")

# eos_list = [eos0,eos1,eos2,eos3,eos4,eos13,eos14,eos15]

fam0 = lalsim.CreateSimNeutronStarFamily(eos0)
fam1 = lalsim.CreateSimNeutronStarFamily(eos1)
fam2 = lalsim.CreateSimNeutronStarFamily(eos2)
fam3 = lalsim.CreateSimNeutronStarFamily(eos3)
fam4 = lalsim.CreateSimNeutronStarFamily(eos4)
# fam5 = lalsim.CreateSimNeutronStarFamily(eos5)
# fam6 = lalsim.CreateSimNeutronStarFamily(eos6)
# fam7 = lalsim.CreateSimNeutronStarFamily(eos7)
# fam8 = lalsim.CreateSimNeutronStarFamily(eos8)
# fam9 = lalsim.CreateSimNeutronStarFamily(eos9)
# fam10 = lalsim.CreateSimNeutronStarFamily(eos10)
# fam11 = lalsim.CreateSimNeutronStarFamily(eos11)
# fam12 = lalsim.CreateSimNeutronStarFamily(eos12)
fam13 = lalsim.CreateSimNeutronStarFamily(eos13)
fam14 = lalsim.CreateSimNeutronStarFamily(eos14)
fam15 = lalsim.CreateSimNeutronStarFamily(eos15)

# fam_list = [fam0,fam1,fam2,fam3,fam4,fam13,fam14,fam15]

# %%
# mass1 = 1.5 #results.posterior['mass_1']

# #Love numeber 
# lov0_m1 = lalsim.SimNeutronStarLoveNumberK2(mass1  * lal.MSUN_SI, fam0)
# lov1_m1 = lalsim.SimNeutronStarLoveNumberK2(mass1 * lal.MSUN_SI, fam1)
# lov2_m1 = lalsim.SimNeutronStarLoveNumberK2(mass1  * lal.MSUN_SI, fam2)
# lov3_m1 = lalsim.SimNeutronStarLoveNumberK2(mass1  * lal.MSUN_SI, fam3)
# lov4_m1 = lalsim.SimNeutronStarLoveNumberK2(mass1  * lal.MSUN_SI, fam4)
# lov13_m1 = lalsim.SimNeutronStarLoveNumberK2(mass1  * lal.MSUN_SI, fam13)
# lov14_m1 = lalsim.SimNeutronStarLoveNumberK2(mass1  * lal.MSUN_SI, fam14)
# lov15_m1 = lalsim.SimNeutronStarLoveNumberK2(mass1  * lal.MSUN_SI, fam15)

# love_m1_list = [lov0_m1,lov1_m1, lov2_m1, lov3_m1, lov4_m1, lov13_m1,lov14_m1,lov15_m1]

# %%
def LoveNumberK2(mass,fam):
    lovenumber = lalsim.SimNeutronStarLoveNumberK2(mass * lal.MSUN_SI, fam)
    return lovenumber
# lovenumber1 = [LoveNumberK2(mass, fam0) for mass in results.posterior['mass_1']]
# print(lovenumber1)

# %%
lov0_m1 = [LoveNumberK2(mass, fam0) for mass in results.posterior['mass_1']]
lov1_m1 = [LoveNumberK2(mass, fam1) for mass in results.posterior['mass_1']]
lov2_m1 = [LoveNumberK2(mass, fam2) for mass in results.posterior['mass_1']]
lov3_m1 = [LoveNumberK2(mass, fam3) for mass in results.posterior['mass_1']]
lov4_m1 = [LoveNumberK2(mass, fam4) for mass in results.posterior['mass_1']]
lov13_m1 = [LoveNumberK2(mass, fam13) for mass in results.posterior['mass_1']]
lov14_m1 = [LoveNumberK2(mass, fam14) for mass in results.posterior['mass_1']]
lov15_m1 = [LoveNumberK2(mass, fam15) for mass in results.posterior['mass_1']]

# %%
sns.scatterplot(x = lov0_m1, y = results.posterior['mass_1']).set(xlabel='lovenumber_m1', ylabel='mass_1')
sns.scatterplot(x = lov1_m1, y = results.posterior['mass_1'])
sns.scatterplot(x = lov2_m1, y = results.posterior['mass_1'])
sns.scatterplot(x = lov3_m1, y = results.posterior['mass_1'])
sns.scatterplot(x = lov4_m1, y = results.posterior['mass_1'])
sns.scatterplot(x = lov13_m1, y = results.posterior['mass_1'])
sns.scatterplot(x = lov14_m1, y = results.posterior['mass_1'])
sns.scatterplot(x = lov15_m1, y = results.posterior['mass_1'])

# plt.xlabel('lovenumber_m1')
# plt.ylabel('mass_1')
# Out:
# <AxesSubplot:xlabel='lovenumber_m1', ylabel='mass_1'>

# %%
lov0_m2 = [LoveNumberK2(mass, fam0) for mass in results.posterior['mass_2']]
lov1_m2 = [LoveNumberK2(mass, fam1) for mass in results.posterior['mass_2']]
lov2_m2 = [LoveNumberK2(mass, fam2) for mass in results.posterior['mass_2']]
lov3_m2 = [LoveNumberK2(mass, fam3) for mass in results.posterior['mass_2']]
lov4_m2 = [LoveNumberK2(mass, fam4) for mass in results.posterior['mass_2']]
lov13_m2 = [LoveNumberK2(mass, fam13) for mass in results.posterior['mass_2']]
lov14_m2 = [LoveNumberK2(mass, fam14) for mass in results.posterior['mass_2']]
lov15_m2 = [LoveNumberK2(mass, fam15) for mass in results.posterior['mass_2']]

# %%
sns.scatterplot(x = lov0_m2, y = results.posterior['mass_2']).set(xlabel='lovenumber_m2', ylabel='mass_2')
sns.scatterplot(x = lov1_m2, y = results.posterior['mass_2'])
sns.scatterplot(x = lov2_m2, y = results.posterior['mass_2'])
sns.scatterplot(x = lov3_m2, y = results.posterior['mass_2'])
sns.scatterplot(x = lov4_m2, y = results.posterior['mass_2'])
sns.scatterplot(x = lov13_m2, y = results.posterior['mass_2'])
sns.scatterplot(x = lov14_m2, y = results.posterior['mass_2'])
sns.scatterplot(x = lov15_m2, y = results.posterior['mass_2'])
# plt.xlabel('lovenumber_m2')
# plt.ylabel('mass_2')
# Out:
# <AxesSubplot:xlabel='lovenumber_m2', ylabel='mass_2'>

# %%
def NSradius(mass,fam):
    radius_calc = lalsim.SimNeutronStarRadius(mass * lal.MSUN_SI, fam)
    return radius_calc

# %%
rad0_m1 = [NSradius(mass, fam0) for mass in results.posterior['mass_1']]
rad1_m1 = [NSradius(mass, fam1) for mass in results.posterior['mass_1']]
rad2_m1 = [NSradius(mass, fam2) for mass in results.posterior['mass_1']]
rad3_m1 = [NSradius(mass, fam3) for mass in results.posterior['mass_1']]
rad4_m1 = [NSradius(mass, fam4) for mass in results.posterior['mass_1']]
rad13_m1 = [NSradius(mass, fam13) for mass in results.posterior['mass_1']]
rad14_m1 = [NSradius(mass, fam14) for mass in results.posterior['mass_1']]
rad15_m1 = [NSradius(mass, fam15) for mass in results.posterior['mass_1']]

# %%
sns.scatterplot(x = rad0_m1, y = results.posterior['mass_1']).set(xlabel='radius_m1', ylabel='mass_1')
sns.scatterplot(x = rad1_m1, y = results.posterior['mass_1'])
sns.scatterplot(x = rad2_m1, y = results.posterior['mass_1'])
sns.scatterplot(x = rad3_m1, y = results.posterior['mass_1'])
sns.scatterplot(x = rad4_m1, y = results.posterior['mass_1'])
sns.scatterplot(x = rad13_m1, y = results.posterior['mass_1'])
sns.scatterplot(x = rad14_m1, y = results.posterior['mass_1'])
sns.scatterplot(x = rad15_m1, y = results.posterior['mass_1'])

# sns.set(xlabel ="radius_m1", ylabel = "mass_1")

# plt.xlabel('radius_m1')
# plt.ylabel('mass_1')
# Out:
# <AxesSubplot:xlabel='radius_m1', ylabel='mass_1'>

# %%
rad0_m2 = [NSradius(mass, fam0) for mass in results.posterior['mass_2']]
rad1_m2 = [NSradius(mass, fam1) for mass in results.posterior['mass_2']]
rad2_m2 = [NSradius(mass, fam2) for mass in results.posterior['mass_2']]
rad3_m2 = [NSradius(mass, fam3) for mass in results.posterior['mass_2']]
rad4_m2 = [NSradius(mass, fam4) for mass in results.posterior['mass_2']]
rad13_m2 = [NSradius(mass, fam13) for mass in results.posterior['mass_2']]
rad14_m2 = [NSradius(mass, fam14) for mass in results.posterior['mass_2']]
rad15_m2 = [NSradius(mass, fam15) for mass in results.posterior['mass_2']]

# %%
sns.scatterplot(x = rad0_m2, y = results.posterior['mass_2']).set(xlabel='radius_m2', ylabel='mass_2')
sns.scatterplot(x = rad1_m2, y = results.posterior['mass_2'])
sns.scatterplot(x = rad2_m2, y = results.posterior['mass_2'])
sns.scatterplot(x = rad3_m2, y = results.posterior['mass_2'])
sns.scatterplot(x = rad4_m2, y = results.posterior['mass_2'])
sns.scatterplot(x = rad13_m2, y = results.posterior['mass_2'])
sns.scatterplot(x = rad14_m2, y = results.posterior['mass_2'])
sns.scatterplot(x = rad15_m2, y = results.posterior['mass_2'])

# .set(xlabel='radius_m2', ylabel='mass_2')

# sns.set(xlabel ="radius_m2", ylabel = "mass_2")
# plt.xlabel('radius_m2')
# plt.ylabel('mass_2')
# Out:
# <AxesSubplot:xlabel='radius_m2', ylabel='mass_2'>

# %%
def Lambda(love, radius, mass ): 
  # takes values in SI units, per LAL convention 
  return (2/3) * love * (((radius / mass)*(lal.C_SI**2/lal.G_SI))**5)

# %%
# print(lov0_m1 * (0.66666666667))

# for x in lov0_m1: 
#     lov0_m1_new = x * (2/3)

    # return lov0_m1_new
    
# Lambda_1_val_0 =

# %%
# print(results.posterior['mass_1'])
# print(lov0_m1_new)

# print((2/3) * lov0_m1)
# print(lov0_m1 * 0.1)

# for x in lov0_m1:
#     lov0_m1 * 0.1

# type(lov0_m1)
# print(lov0_m1[0]*2.3)

## a = [love*(2/3) for love in lov0_m1]
# print(a)
# b = [love*(2/3) for love in lov0_m1]

# b = [(radius/mass) *(lal.C_SI**2/lal.G_SI)**5 for radius,mass in zip(rad0_m1,results.posterior['mass_1'])]

# %%
# def Lambda(love, radius, mass ): 
#   # takes values in SI units, per LAL convention 
#   return (2/3) * love * (((radius / mass)*(lal.C_SI**2/lal.G_SI))**5)

def Lambda(love_list,rad_list,mass_list):
    a = [love*(2/3) for love in love_list] 
    # rad_mass = [love*(2/3) for love in radius]
    # calc = a * rad_mass *(lal.C_SI**2/lal.G_SI)**5
    b = [((radius/mass) *(lal.C_SI**2/lal.G_SI))**5 for radius,mass in zip(rad_list,mass_list)]
    c = [a * b for a,b in zip(a, b)]
    return c

# %%
# print(Lambda(lov0_m1,rad0_m1))
Lambda_1_val_0 = Lambda(lov0_m1, rad0_m1, results.posterior['mass_1'] * lal.MSUN_SI)
Lambda_1_val_1 = Lambda(lov1_m1, rad1_m1, results.posterior['mass_1'] * lal.MSUN_SI)
Lambda_1_val_2 = Lambda(lov2_m1, rad2_m1, results.posterior['mass_1'] * lal.MSUN_SI)
Lambda_1_val_3 = Lambda(lov3_m1, rad3_m1, results.posterior['mass_1'] * lal.MSUN_SI)
Lambda_1_val_4 = Lambda(lov4_m1, rad4_m1, results.posterior['mass_1'] * lal.MSUN_SI)
Lambda_1_val_13 = Lambda(lov13_m1, rad13_m1, results.posterior['mass_1'] * lal.MSUN_SI)
Lambda_1_val_14 = Lambda(lov14_m1, rad14_m1, results.posterior['mass_1'] * lal.MSUN_SI)
Lambda_1_val_15 = Lambda(lov15_m1, rad15_m1, results.posterior['mass_1'] * lal.MSUN_SI)

# %%
sns.scatterplot(x = Lambda_1_val_0, y = results.posterior['mass_1']).set(xlabel='lambda1_m1', ylabel='mass_1')
sns.scatterplot(x = Lambda_1_val_1, y = results.posterior['mass_1'])
sns.scatterplot(x = Lambda_1_val_2, y = results.posterior['mass_1'])
sns.scatterplot(x = Lambda_1_val_3, y = results.posterior['mass_1'])
sns.scatterplot(x = Lambda_1_val_4, y = results.posterior['mass_1'])
sns.scatterplot(x = Lambda_1_val_13, y = results.posterior['mass_1'])
sns.scatterplot(x = Lambda_1_val_14, y = results.posterior['mass_1'])
sns.scatterplot(x = Lambda_1_val_15, y = results.posterior['mass_1'])

# plt.xlabel('lambda_m1')
# plt.ylabel('mass_1')
# Out:
# <AxesSubplot:xlabel='lambda1_m1', ylabel='mass_1'>

# %%
# Lambda_val_1 = Lambda(lov, rad, results.posterior['mass_1'] * lal.MSUN_SI)

# Lambda_1_val_0 = Lambda(lov0_m1, rad0_m1, results.posterior['mass_1'] * lal.MSUN_SI)
# Lambda_1_val_1 = Lambda(lov1_m1, rad1_m1, results.posterior['mass_1'] * lal.MSUN_SI)
# Lambda_1_val_2 = Lambda(lov2_m1, rad2_m1, results.posterior['mass_1'] * lal.MSUN_SI)
# Lambda_1_val_3 = Lambda(lov3_m1, rad3_m1, results.posterior['mass_1'] * lal.MSUN_SI)
# Lambda_1_val_4 = Lambda(lov4_m1, rad4_m1, results.posterior['mass_1'] * lal.MSUN_SI)
# Lambda_1_val_13 = Lambda(lov13_m1, rad13_m1, results.posterior['mass_1'] * lal.MSUN_SI)
# Lambda_1_val_14 = Lambda(lov14_m1, rad14_m1, results.posterior['mass_1'] * lal.MSUN_SI)
# Lambda_1_val_15 = Lambda(lov15_m1, rad15_m1, results.posterior['mass_1'] * lal.MSUN_SI)

# %%
Lambda_2_val_0 = Lambda(lov0_m2, rad0_m2, results.posterior['mass_2'] * lal.MSUN_SI)
Lambda_2_val_1 = Lambda(lov1_m2, rad1_m2, results.posterior['mass_2'] * lal.MSUN_SI)
Lambda_2_val_2 = Lambda(lov2_m2, rad2_m2, results.posterior['mass_2'] * lal.MSUN_SI)
Lambda_2_val_3 = Lambda(lov3_m2, rad3_m2, results.posterior['mass_2'] * lal.MSUN_SI)
Lambda_2_val_4 = Lambda(lov4_m2, rad4_m2, results.posterior['mass_2'] * lal.MSUN_SI)
Lambda_2_val_13 = Lambda(lov13_m2, rad13_m2, results.posterior['mass_2'] * lal.MSUN_SI)
Lambda_2_val_14 = Lambda(lov14_m2, rad14_m2, results.posterior['mass_2'] * lal.MSUN_SI)
Lambda_2_val_15 = Lambda(lov15_m2, rad15_m2, results.posterior['mass_2'] * lal.MSUN_SI)

# %%
sns.scatterplot(x = Lambda_2_val_0, y = results.posterior['mass_2']).set(xlabel='lambda2_m2', ylabel='mass_2')
sns.scatterplot(x = Lambda_2_val_1, y = results.posterior['mass_2'])
sns.scatterplot(x = Lambda_2_val_2, y = results.posterior['mass_2'])
sns.scatterplot(x = Lambda_2_val_3, y = results.posterior['mass_2'])
sns.scatterplot(x = Lambda_2_val_4, y = results.posterior['mass_2'])
sns.scatterplot(x = Lambda_2_val_13, y = results.posterior['mass_2'])
sns.scatterplot(x = Lambda_2_val_14, y = results.posterior['mass_2'])
sns.scatterplot(x = Lambda_2_val_15, y = results.posterior['mass_2'])

# plt.xlabel('lambda_m2')
# plt.ylabel('mass_2')
# Out:
# <AxesSubplot:xlabel='lambda2_m2', ylabel='mass_2'>

# %%
# Lambda_val_2 = Lambda(lov, rad, results.posterior['mass_2']* lal.MSUN_SI)

# Lambda_2_val_0 = Lambda(lov0_m2, rad0_m2, results.posterior['mass_2'] * lal.MSUN_SI)
# Lambda_2_val_1 = Lambda(lov1_m2, rad1_m2, results.posterior['mass_2'] * lal.MSUN_SI)
# Lambda_2_val_2 = Lambda(lov2_m2, rad2_m2, results.posterior['mass_2'] * lal.MSUN_SI)
# Lambda_2_val_3 = Lambda(lov3_m2, rad3_m2, results.posterior['mass_2'] * lal.MSUN_SI)
# Lambda_2_val_4 = Lambda(lov4_m2, rad4_m2, results.posterior['mass_2'] * lal.MSUN_SI)
# Lambda_2_val_13 = Lambda(lov13_m2, rad13_m2, results.posterior['mass_2'] * lal.MSUN_SI)
# Lambda_2_val_14 = Lambda(lov14_m2, rad14_m2, results.posterior['mass_2'] * lal.MSUN_SI)
# Lambda_2_val_15 = Lambda(lov15_m2, rad15_m2, results.posterior['mass_2'] * lal.MSUN_SI)

# %%
# results = bilby.result.read_in_result(filename='binary_love_Symm/outdir/bns_example_result.json') #Binary_love_Symm

# %%
# sns.kdeplot( x=results.posterior['lambda_1'], y=results.posterior['lambda_2'],color = 'green', label='Binary_love_&_LambdaSymm')

# %%
# sns.lineplot( x=Lambda_val_1, y=Lambda_val_2, label='Binary_love_&_LambdaSymm')

sns.scatterplot( x=Lambda_1_val_0, y=Lambda_2_val_0, label='SLY').set(xlabel='lambda1', ylabel='lambda2')

sns.scatterplot( x=Lambda_1_val_1, y=Lambda_2_val_1,label='ALF2')

sns.scatterplot( x=Lambda_1_val_2, y=Lambda_2_val_2,label='H4')

sns.scatterplot( x=Lambda_1_val_3, y=Lambda_2_val_3,label='MPA1')

sns.scatterplot( x=Lambda_1_val_4, y=Lambda_2_val_4,label='ENG')

sns.scatterplot( x=Lambda_1_val_13, y=Lambda_2_val_13,label='HQC18')

sns.scatterplot( x=Lambda_1_val_14, y=Lambda_2_val_14,label='SKOP')

sns.scatterplot( x=Lambda_1_val_15, y=Lambda_2_val_15,label='BHF_BBB2')
# Out:
# <AxesSubplot:xlabel='lambda1', ylabel='lambda2'>

# %%
sns.kdeplot( x=results.posterior['lambda_1'], y=results.posterior['lambda_2'],color = 'gray', label='Binary_love_&_LambdaSymm')
# sns.lineplot( x=Lambda_val_1, y=Lambda_val_2,color = 'blue', label='SLY')
sns.scatterplot( x=Lambda_1_val_0, y=Lambda_2_val_0, label='SLY')

sns.scatterplot( x=Lambda_1_val_1, y=Lambda_2_val_1,label='ALF2')

sns.scatterplot( x=Lambda_1_val_3, y=Lambda_2_val_3,label='MPA1')

sns.scatterplot( x=Lambda_1_val_4, y=Lambda_2_val_4,label='ENG')

sns.scatterplot( x=Lambda_1_val_13, y=Lambda_2_val_13,label='HQC18')

sns.scatterplot( x=Lambda_1_val_14, y=Lambda_2_val_14,label='SKOP')

sns.scatterplot( x=Lambda_1_val_15, y=Lambda_2_val_15,label='BHF_BBB2')

sns.scatterplot( x=Lambda_1_val_2, y=Lambda_2_val_2,label='H4', color = 'green')

plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)


gray_line = mlines.Line2D(results.posterior['lambda_1'], results.posterior['lambda_2'], color='gray', label='Binary_love_&_LambdaSymm')
# red_line = mlines.Line2D(result_3.posterior['lambda_1'], result_3.posterior['lambda_2'], color='red', label='BinaryLove and $\Lambda_S$')
# black_line = mlines.Line2D(result_3.injection_parameters['lambda_1'],result_3.injection_parameters['lambda_2'], color='black', label='Injection Sample')
plt.legend(handles=[gray_line])

# %%
sns.scatterplot( x=results.posterior['mass_1'], y=results.posterior['mass_2'])
#test#
# Out:
# <AxesSubplot:xlabel='mass_1', ylabel='mass_2'>

# %%
sns.scatterplot(x = lov0_m1, y = results.posterior['mass_1'],color = "blue")
sns.scatterplot(x = lov1_m1, y = results.posterior['mass_1'],color = "blue")
sns.scatterplot(x = lov2_m1, y = results.posterior['mass_1'],color = "blue")
sns.scatterplot(x = lov3_m1, y = results.posterior['mass_1'],color = "blue")
sns.scatterplot(x = lov4_m1, y = results.posterior['mass_1'],color = "blue")
sns.scatterplot(x = lov13_m1, y = results.posterior['mass_1'],color = "blue")
sns.scatterplot(x = lov14_m1, y = results.posterior['mass_1'],color = "blue")
sns.scatterplot(x = lov15_m1, y = results.posterior['mass_1'],color = "blue")

sns.scatterplot(x = lov0_m2, y = results.posterior['mass_2'],color = "green").set(xlabel='lovenumber', ylabel='masses')
sns.scatterplot(x = lov1_m2, y = results.posterior['mass_2'],color = "green")
sns.scatterplot(x = lov2_m2, y = results.posterior['mass_2'],color = "green")
sns.scatterplot(x = lov3_m2, y = results.posterior['mass_2'],color = "green")
sns.scatterplot(x = lov4_m2, y = results.posterior['mass_2'],color = "green")
sns.scatterplot(x = lov13_m2, y = results.posterior['mass_2'],color = "green")
sns.scatterplot(x = lov14_m2, y = results.posterior['mass_2'],color = "green")
sns.scatterplot(x = lov15_m2, y = results.posterior['mass_2'],color = "green")
# plt.xlabel('lovenumber_m2')
# plt.ylabel('mass_2')


# plt.xlabel('lovenumber_m1')
# plt.ylabel('mass_1')
# Out:
# <AxesSubplot:xlabel='lovenumber', ylabel='masses'>

# %%
sns.scatterplot(x = rad0_m1, y = results.posterior['mass_1'],color = "blue")#.set(xlabel='radius_m1', ylabel='mass_1')
sns.scatterplot(x = rad1_m1, y = results.posterior['mass_1'],color = "blue")
sns.scatterplot(x = rad2_m1, y = results.posterior['mass_1'],color = "blue")
sns.scatterplot(x = rad3_m1, y = results.posterior['mass_1'],color = "blue")
sns.scatterplot(x = rad4_m1, y = results.posterior['mass_1'],color = "blue")
sns.scatterplot(x = rad13_m1, y = results.posterior['mass_1'],color = "blue")
sns.scatterplot(x = rad14_m1, y = results.posterior['mass_1'],color = "blue")
sns.scatterplot(x = rad15_m1, y = results.posterior['mass_1'],color = "blue")

sns.scatterplot(x = rad0_m2, y = results.posterior['mass_2'],color = "green").set(xlabel='radius', ylabel='masses')
sns.scatterplot(x = rad1_m2, y = results.posterior['mass_2'],color = "green")
sns.scatterplot(x = rad2_m2, y = results.posterior['mass_2'],color = "green")
sns.scatterplot(x = rad3_m2, y = results.posterior['mass_2'],color = "green")
sns.scatterplot(x = rad4_m2, y = results.posterior['mass_2'],color = "green")
sns.scatterplot(x = rad13_m2, y = results.posterior['mass_2'],color = "green")
sns.scatterplot(x = rad14_m2, y = results.posterior['mass_2'],color = "green")
sns.scatterplot(x = rad15_m2, y = results.posterior['mass_2'],color = "green")
# Out:
# <AxesSubplot:xlabel='radius', ylabel='masses'>

# %%
# #love1 vs love2
# sns.scatterplot(x = lov0_m1, y = lov0_m2).set(xlabel='lov_m1', ylabel='lov_m2')
# sns.scatterplot(x = lov1_m1, y = lov1_m2)
# sns.scatterplot(x = lov2_m1, y = lov2_m2)
# sns.scatterplot(x = lov3_m1, y = lov3_m2)
# sns.scatterplot(x = lov4_m1, y = lov4_m2)
# sns.scatterplot(x = lov13_m1, y = lov13_m2)
# sns.scatterplot(x = lov14_m1, y = lov14_m2)
# sns.scatterplot(x = lov15_m1, y = lov15_m2)

# %%
##rad1 vs rad2

# sns.scatterplot(x = rad0_m1, y = rad0_m2).set(xlabel='radius_m1', ylabel='radius_m2')
# sns.scatterplot(x = rad1_m1, y = rad1_m2)
# sns.scatterplot(x = rad2_m1, y = rad2_m2)
# sns.scatterplot(x = rad3_m1, y = rad3_m2)
# sns.scatterplot(x = rad4_m1, y = rad4_m2)
# sns.scatterplot(x = rad13_m1, y = rad13_m2)
# sns.scatterplot(x = rad14_m1, y = rad14_m2)
# sns.scatterplot(x = rad15_m1, y = rad15_m2)

# %%
# result_1 = bilby.result.read_in_result(filename='lambdatilde_deltalambdatilde/outdir/New_Example_Code_result.json') #Bilby_Example_Code_Carls_Import

# %%
# result_1.posterior['lambda1'] = result_1.posterior.apply(lambda row :
#         bilby.gw.conversion.lambda_tilde_delta_lambda_tilde_to_lambda_1_lambda_2(
#                 row['lambda_tilde'],row['delta_lambda'],row['mass_1'],row['mass_2']
#                 )[0], axis = 1)
# result_1.posterior['lambda2'] = result_1.posterior.apply(lambda row :
#         bilby.gw.conversion.lambda_tilde_delta_lambda_tilde_to_lambda_1_lambda_2(
#                 row['lambda_tilde'],row['delta_lambda'],row['mass_1'],row['mass_2']
#                 )[1], axis = 1)

# %%
# sns.kdeplot( x=result_1.posterior['lambda1'], y=result_1.posterior['lambda2'],color = 'orange')

# %%
# sns.kdeplot( x=result_1.posterior['lambda1'], y=result_1.posterior['lambda2'], color = "gray",label='deltalambda & lambdatilde')
# sns.kdeplot( x=results.posterior['lambda_1'], y=results.posterior['lambda_2'], label='Binary_love_&_LambdaSymm')
# # sns.lineplot( x=Lambda_val_1, y=Lambda_val_2,color = 'blue', label='SLY')
# sns.lineplot( x=Lambda_1_val_0, y=Lambda_2_val_0, label='SLY')

# sns.lineplot( x=Lambda_1_val_1, y=Lambda_2_val_1,label='ALF2')

# sns.lineplot( x=Lambda_1_val_3, y=Lambda_2_val_3,label='MPA1')

# sns.lineplot( x=Lambda_1_val_4, y=Lambda_2_val_4,label='ENG')

# sns.lineplot( x=Lambda_1_val_13, y=Lambda_2_val_13,label='HQC18')

# sns.lineplot( x=Lambda_1_val_14, y=Lambda_2_val_14,label='SKOP')

# sns.lineplot( x=Lambda_1_val_15, y=Lambda_2_val_15,label='BHF_BBB2')

# sns.lineplot( x=Lambda_1_val_2, y=Lambda_2_val_2,label='H4')

# plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

# blue_line = mlines.Line2D(result_1.posterior['lambda_1'], result_1.posterior['lambda_2'], color='gray', label='deltalambda & lambdatilde')
# red_line = mlines.Line2D(results.posterior['lambda_1'], results.posterior['lambda_2'], label='BinaryLove and $\Lambda_S$')
# # black_line = mlines.Line2D(result_3.injection_parameters['lambda_1'],result_3.injection_parameters['lambda_2'], color='black', label='Injection Sample')
# plt.legend(handles=[blue_line, red_line])

# %%
#Getting data of prior weights:
